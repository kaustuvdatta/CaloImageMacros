# %%
#Import all necessary packages
#The generator is in nn_packages script
from nn_packages import *
from io_functions import *
import numpy as np
import root_numpy as rnp
import os
import sys
import re
import glob
import h5py
import numpy as np
import math
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import EarlyStopping, ModelCheckpoint
# %matplotlib inline
import matplotlib.pyplot as plt
from keras.utils.visualize_util import plot
# Out:
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN not available)
# Using Theano backend.
# Couldn't import dot_parser, loading of dot files will not be possible.
# /usr/local/lib/python2.7/dist-packages/root_numpy/__init__.py:35: RuntimeWarning: numpy 1.11.1 is currently installed but you installed root_numpy against numpy 1.11.0. Please consider reinstalling root_numpy for this numpy version.
#   RuntimeWarning)
# Welcome to ROOTaaS 6.06/04

# %%
def loadmodel(name):
    json_file = open('%s.json'%name, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)
    #load weights into new model
    #model.load_weights('%s_w.h5'%name)
    print (model.summary())
    print("Loaded model from disk")
    return model

def savemodel(model,name="neural network"):

    model_name = name
    model.summary()
    model.save_weights('%s.h5'%model_name, overwrite=True)
    model_json = model.to_json()
    with open("%s.json"%model_name, "w") as json_file:
        json_file.write(model_json)
        
def savelosses(hist, name="neural network"):    
    loss = np.array(hist.history['loss'])
    valoss = np.array(hist.history['val_loss'])
    f = h5py.File("%s_losses.h5"%name,"w")
    f.create_dataset('loss',data=loss)
    f.create_dataset('val_loss',data=valoss)
    f.close()

# %%
cnn1 = loadmodel('/home/kaustuv1993/Notebooks/Models_and_Weights/cnn2d_datagen_DOES_1')
cnn2 = loadmodel('/home/kaustuv1993/Notebooks/Models_and_Weights/cnn2d_datagen_DOES_2')
cnn3 = loadmodel("/home/kaustuv1993/Notebooks/Models_and_Weights/cnn3D_datagen_DOES_600_leaky")
cnn4 = loadmodel("/home/kaustuv1993/Notebooks/Models_and_Weights/cnn2d_datagen_DOES_3_500")
cnn3d = loadmodel("/home/kaustuv1993/Notebooks/Models_and_Weights/cnn3D_datagen_DOES_600")
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# convolution2d_1 (Convolution2D)  (None, 10, 17, 17)    4010        convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 10, 8, 8)      0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 640)           0           maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 10000)         6410000     flatten_1[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
plot(cnn3d,to_file='drawn_models/cnn3d.png', show_shapes=True,
               show_layer_names=False)
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %%
for k in xrange(1,7):
    filename='bcnn%d_cl'%k
    #if k==1:
        #continue
    if k==6:
        filename='dense1_reg'
    model = loadmodel("/data/shared/LCD/Final/Regression/%s"%filename)
    plot(model,to_file='drawn_models/'+filename+'.png', show_shapes=True, show_layer_names=False)
    print('drawn models '+filename)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 1, 24, 24, 25) 0
# ____________________________________________________________________________________________________
# input_2 (InputLayer)             (None, 1, 4, 4, 60)   0
# ____________________________________________________________________________________________________
# convolution3d_1 (Convolution3D)  (None, 10, 21, 21, 21)810         input_1[0][0]
# ____________________________________________________________________________________________________
# convolution3d_2 (Convolution3D)  (None, 10, 3, 3, 55)  250         input_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling3d_1 (MaxPooling3D)    (None, 10, 10, 10, 10)0           convolution3d_1[0][0]
# ...
