# %%
import sys
import re
import glob
from io_functions import *
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN not available)
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
from nn_packages import * 
from nn_graphics import * 
import numpy as np
# Out:
# Welcome to ROOTaaS 6.06/04

# %%
def find_energy(filename):
    index1 = filename.find('_')
    index2 = filename.find('Ge', index1 + 1)
    try:
        return int(filename[index2+1:index2+4])
    except:
        return int(filename[index2+1:index2+3])

# %%
nf=0
l=0
for file in os.listdir("/home/kaustuv1993/Data/GammaEscan"):
    if file.endswith("GeV.h5"):
        nf+=1
        l=len(file)
print(nf)
print(l)

#signal=get_dataset("/home/kaustuv1993/Data/GammaEscan/")
#save_dataset("/home/kaustuv1993/Data/GammaEscan/", signal)
#print signals
# Out:
# 2000
# 22

# %%
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
for i in xrange(108,110):
    d=get_dataset('/data/shared/LCD/GammaEscan/GammaEscan_*_%dGeV' %i)
    save_dataset('Energy_Scan_Gamma/GammaEscan_%dGeV'%i, d)
    print i
print len(d)
# Out:
# io_functions.py:38: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if big==None:
# io_functions.py:45: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if big!=None:
# init
# (10000, 20, 20, 25)
# 108
# init
# (10000, 20, 20, 25)
# 109
# 10000

# %%
for i in xrange(10,110):
    d=get_dataset('/data/shared/LCD/Pi0Escan/Pi0Escan_*_%dGeV' %i)
    save_dataset('Pi0Escan_%dGeV'%i, d)
    
    print i
print len(d)

# %%
#fnames=np.chararray(nf,itemsize=23)
temp=np.empty([])
i=0
for file in os.listdir("/home/kaustuv1993/Data/Energy_Scan_Gamma/"):
    if file.endswith(".h5"):
        print file
        #fnames[i]=file
        en=int(filter(str.isdigit,(file)))/10
        
        i+=1 
#print fnames
# Out:
# GammaEscan_74GeV_fulldataset.h5
# 74
# GammaEscan_97GeV_fulldataset.h5
# 97
# GammaEscan_53GeV_fulldataset.h5
# 53
# GammaEscan_11GeV_fulldataset.h5
# 11
# GammaEscan_51GeV_fulldataset.h5
# 51
# GammaEscan_14GeV_fulldataset.h5
# 14
# GammaEscan_98GeV_fulldataset.h5
# 98
# GammaEscan_27GeV_fulldataset.h5
# 27
# GammaEscan_39GeV_fulldataset.h5
# 39
# GammaEscan_19GeV_fulldataset.h5
# 19
# GammaEscan_37GeV_fulldataset.h5
# 37
# GammaEscan_30GeV_fulldataset.h5
# 30
# GammaEscan_102GeV_fulldataset.h5
# 102
# GammaEscan_71GeV_fulldataset.h5
# 71
# GammaEscan_66GeV_fulldataset.h5
# 66
# GammaEscan_103GeV_fulldataset.h5
# 103
# GammaEscan_82GeV_fulldataset.h5
# 82
# GammaEscan_25GeV_fulldataset.h5
# 25
# GammaEscan_73GeV_fulldataset.h5
# 73
# GammaEscan_50GeV_fulldataset.h5
# 50
# GammaEscan_54GeV_fulldataset.h5
# 54
# GammaEscan_78GeV_fulldataset.h5
# 78
# GammaEscan_94GeV_fulldataset.h5
# 94
# GammaEscan_17GeV_fulldataset.h5
# 17
# GammaEscan_87GeV_fulldataset.h5
# 87
# GammaEscan_68GeV_fulldataset.h5
# 68
# GammaEscan_99GeV_fulldataset.h5
# 99
# GammaEscan_60GeV_fulldataset.h5
# 60
# GammaEscan_109GeV_fulldataset.h5
# 109
# GammaEscan_86GeV_fulldataset.h5
# 86
# GammaEscan_85GeV_fulldataset.h5
# 85
# GammaEscan_47GeV_fulldataset.h5
# 47
# GammaEscan_32GeV_fulldataset.h5
# 32
# GammaEscan_18GeV_fulldataset.h5
# 18
# GammaEscan_83GeV_fulldataset.h5
# 83
# GammaEscan_95GeV_fulldataset.h5
# 95
# GammaEscan_90GeV_fulldataset.h5
# 90
# GammaEscan_67GeV_fulldataset.h5
# 67
# GammaEscan_52GeV_fulldataset.h5
# 52
# GammaEscan_108GeV_fulldataset.h5
# 108
# GammaEscan_79GeV_fulldataset.h5
# 79
# GammaEscan_34GeV_fulldataset.h5
# 34
# GammaEscan_44GeV_fulldataset.h5
# 44
# GammaEscan_80GeV_fulldataset.h5
# 80
# GammaEscan_72GeV_fulldataset.h5
# 72
# GammaEscan_35GeV_fulldataset.h5
# 35
# GammaEscan_21GeV_fulldataset.h5
# 21
# GammaEscan_70GeV_fulldataset.h5
# 70
# GammaEscan_24GeV_fulldataset.h5
# 24
# GammaEscan_49GeV_fulldataset.h5
# 49
# GammaEscan_26GeV_fulldataset.h5
# 26
# GammaEscan_33GeV_fulldataset.h5
# 33
# GammaEscan_75GeV_fulldataset.h5
# 75
# GammaEscan_56GeV_fulldataset.h5
# 56
# GammaEscan_100GeV_fulldataset.h5
# 100
# GammaEscan_45GeV_fulldataset.h5
# 45
# GammaEscan_89GeV_fulldataset.h5
# 89
# GammaEscan_55GeV_fulldataset.h5
# 55
# GammaEscan_57GeV_fulldataset.h5
# 57
# GammaEscan_16GeV_fulldataset.h5
# 16
# GammaEscan_64GeV_fulldataset.h5
# 64
# GammaEscan_22GeV_fulldataset.h5
# 22
# GammaEscan_81GeV_fulldataset.h5
# 81
# GammaEscan_76GeV_fulldataset.h5
# 76
# GammaEscan_15GeV_fulldataset.h5
# 15
# GammaEscan_13GeV_fulldataset.h5
# 13
# GammaEscan_48GeV_fulldataset.h5
# 48
# GammaEscan_20GeV_fulldataset.h5
# 20
# GammaEscan_88GeV_fulldataset.h5
# 88
# GammaEscan_92GeV_fulldataset.h5
# 92
# GammaEscan_29GeV_fulldataset.h5
# 29
# GammaEscan_77GeV_fulldataset.h5
# 77
# GammaEscan_10GeV_fulldataset.h5
# 10
# GammaEscan_46GeV_fulldataset.h5
# 46
# GammaEscan_84GeV_fulldataset.h5
# 84
# GammaEscan_63GeV_fulldataset.h5
# 63
# GammaEscan_96GeV_fulldataset.h5
# 96
# GammaEscan_104GeV_fulldataset.h5
# 104
# GammaEscan_61GeV_fulldataset.h5
# 61
# GammaEscan_59GeV_fulldataset.h5
# 59
# GammaEscan_58GeV_fulldataset.h5
# 58
# GammaEscan_62GeV_fulldataset.h5
# 62
# GammaEscan_101GeV_fulldataset.h5
# 101
# GammaEscan_107GeV_fulldataset.h5
# 107
# GammaEscan_40GeV_fulldataset.h5
# 40
# GammaEscan_36GeV_fulldataset.h5
# 36
# GammaEscan_31GeV_fulldataset.h5
# 31
# GammaEscan_69GeV_fulldataset.h5
# 69
# GammaEscan_43GeV_fulldataset.h5
# 43
# GammaEscan_41GeV_fulldataset.h5
# 41
# GammaEscan_91GeV_fulldataset.h5
# 91
# GammaEscan_12GeV_fulldataset.h5
# 12
# GammaEscan_23GeV_fulldataset.h5
# 23
# GammaEscan_38GeV_fulldataset.h5
# 38
# GammaEscan_42GeV_fulldataset.h5
# 42
# GammaEscan_65GeV_fulldataset.h5
# 65
# GammaEscan_105GeV_fulldataset.h5
# 105
# GammaEscan_93GeV_fulldataset.h5
# 93
# GammaEscan_106GeV_fulldataset.h5
# 106
# GammaEscan_28GeV_fulldataset.h5
# 28

# %%
#changing labels on the photon files
import sys
for i in xrange(10, 110):
    fname=("/home/kaustuv1993/Data/Energy_Scan_Gamma/GammaEscan_%dGeV_fulldataset.h5"%i)
    f=h5py.File(fname,'r+')
    if i<100:
        fname=fname[-31:]
        fname=fname[0:28]
        print fname
    if i>100:
        fname=fname[-32:]
        fname=fname[0:29]
        print fname
    print i, f.keys()
    
    en=int(filter(str.isdigit,(fname)))
    target = np.zeros((f['images'].shape[0], 2))
    target[:,0] = 1
    target[:,1] = en
    f['target'] = target
    f.close()
    f.keys()
# Out:
# GammaEscan_10GeV_fulldataset
# 10 [u'images', u'target']
# GammaEscan_11GeV_fulldataset
# 11 [u'images', u'target']
# GammaEscan_12GeV_fulldataset
# 12 [u'images', u'target']
# GammaEscan_13GeV_fulldataset
# 13 [u'images', u'target']
# GammaEscan_14GeV_fulldataset
# 14 [u'images', u'target']
# GammaEscan_15GeV_fulldataset
# 15 [u'images', u'target']
# GammaEscan_16GeV_fulldataset
# 16 [u'images', u'target']
# GammaEscan_17GeV_fulldataset
# 17 [u'images', u'target']
# GammaEscan_18GeV_fulldataset
# 18 [u'images', u'target']
# GammaEscan_19GeV_fulldataset
# 19 [u'images', u'target']
# GammaEscan_20GeV_fulldataset
# 20 [u'images', u'target']
# GammaEscan_21GeV_fulldataset
# 21 [u'images', u'target']
# GammaEscan_22GeV_fulldataset
# 22 [u'images', u'target']
# GammaEscan_23GeV_fulldataset
# 23 [u'images', u'target']
# GammaEscan_24GeV_fulldataset
# 24 [u'images', u'target']
# GammaEscan_25GeV_fulldataset
# 25 [u'images', u'target']
# GammaEscan_26GeV_fulldataset
# 26 [u'images', u'target']
# GammaEscan_27GeV_fulldataset
# 27 [u'images', u'target']
# GammaEscan_28GeV_fulldataset
# 28 [u'images', u'target']
# GammaEscan_29GeV_fulldataset
# 29 [u'images', u'target']
# GammaEscan_30GeV_fulldataset
# 30 [u'images', u'target']
# GammaEscan_31GeV_fulldataset
# 31 [u'images', u'target']
# GammaEscan_32GeV_fulldataset
# 32 [u'images', u'target']
# GammaEscan_33GeV_fulldataset
# 33 [u'images', u'target']
# GammaEscan_34GeV_fulldataset
# 34 [u'images', u'target']
# GammaEscan_35GeV_fulldataset
# 35 [u'images', u'target']
# GammaEscan_36GeV_fulldataset
# 36 [u'images', u'target']
# GammaEscan_37GeV_fulldataset
# 37 [u'images', u'target']
# GammaEscan_38GeV_fulldataset
# 38 [u'images', u'target']
# GammaEscan_39GeV_fulldataset
# 39 [u'images', u'target']
# GammaEscan_40GeV_fulldataset
# 40 [u'images', u'target']
# GammaEscan_41GeV_fulldataset
# 41 [u'images', u'target']
# GammaEscan_42GeV_fulldataset
# 42 [u'images', u'target']
# GammaEscan_43GeV_fulldataset
# 43 [u'images', u'target']
# GammaEscan_44GeV_fulldataset
# 44 [u'images', u'target']
# GammaEscan_45GeV_fulldataset
# 45 [u'images', u'target']
# GammaEscan_46GeV_fulldataset
# 46 [u'images', u'target']
# GammaEscan_47GeV_fulldataset
# 47 [u'images', u'target']
# GammaEscan_48GeV_fulldataset
# 48 [u'images', u'target']
# GammaEscan_49GeV_fulldataset
# 49 [u'images', u'target']
# GammaEscan_50GeV_fulldataset
# 50 [u'images', u'target']
# GammaEscan_51GeV_fulldataset
# 51 [u'images', u'target']
# GammaEscan_52GeV_fulldataset
# 52 [u'images', u'target']
# GammaEscan_53GeV_fulldataset
# 53 [u'images', u'target']
# GammaEscan_54GeV_fulldataset
# 54 [u'images', u'target']
# GammaEscan_55GeV_fulldataset
# 55 [u'images', u'target']
# GammaEscan_56GeV_fulldataset
# 56 [u'images', u'target']
# GammaEscan_57GeV_fulldataset
# 57 [u'images', u'target']
# GammaEscan_58GeV_fulldataset
# 58 [u'images', u'target']
# GammaEscan_59GeV_fulldataset
# 59 [u'images', u'target']
# GammaEscan_60GeV_fulldataset
# 60 [u'images', u'target']
# GammaEscan_61GeV_fulldataset
# 61 [u'images', u'target']
# GammaEscan_62GeV_fulldataset
# 62 [u'images', u'target']
# GammaEscan_63GeV_fulldataset
# 63 [u'images', u'target']
# GammaEscan_64GeV_fulldataset
# 64 [u'images', u'target']
# GammaEscan_65GeV_fulldataset
# 65 [u'images', u'target']
# GammaEscan_66GeV_fulldataset
# 66 [u'images', u'target']
# GammaEscan_67GeV_fulldataset
# 67 [u'images', u'target']
# GammaEscan_68GeV_fulldataset
# 68 [u'images', u'target']
# GammaEscan_69GeV_fulldataset
# 69 [u'images', u'target']
# GammaEscan_70GeV_fulldataset
# 70 [u'images', u'target']
# GammaEscan_71GeV_fulldataset
# 71 [u'images', u'target']
# GammaEscan_72GeV_fulldataset
# 72 [u'images', u'target']
# GammaEscan_73GeV_fulldataset
# 73 [u'images', u'target']
# GammaEscan_74GeV_fulldataset
# 74 [u'images', u'target']
# GammaEscan_75GeV_fulldataset
# 75 [u'images', u'target']
# GammaEscan_76GeV_fulldataset
# 76 [u'images', u'target']
# GammaEscan_77GeV_fulldataset
# 77 [u'images', u'target']
# GammaEscan_78GeV_fulldataset
# 78 [u'images', u'target']
# GammaEscan_79GeV_fulldataset
# 79 [u'images', u'target']
# GammaEscan_80GeV_fulldataset
# 80 [u'images', u'target']
# GammaEscan_81GeV_fulldataset
# 81 [u'images', u'target']
# GammaEscan_82GeV_fulldataset
# 82 [u'images', u'target']
# GammaEscan_83GeV_fulldataset
# 83 [u'images', u'target']
# GammaEscan_84GeV_fulldataset
# 84 [u'images', u'target']
# GammaEscan_85GeV_fulldataset
# 85 [u'images', u'target']
# GammaEscan_86GeV_fulldataset
# 86 [u'images', u'target']
# GammaEscan_87GeV_fulldataset
# 87 [u'images', u'target']
# GammaEscan_88GeV_fulldataset
# 88 [u'images', u'target']
# GammaEscan_89GeV_fulldataset
# 89 [u'images', u'target']
# GammaEscan_90GeV_fulldataset
# 90 [u'images', u'target']
# GammaEscan_91GeV_fulldataset
# 91 [u'images', u'target']
# GammaEscan_92GeV_fulldataset
# 92 [u'images', u'target']
# GammaEscan_93GeV_fulldataset
# 93 [u'images', u'target']
# GammaEscan_94GeV_fulldataset
# 94 [u'images', u'target']
# GammaEscan_95GeV_fulldataset
# 95 [u'images', u'target']
# GammaEscan_96GeV_fulldataset
# 96 [u'images', u'target']
# GammaEscan_97GeV_fulldataset
# 97 [u'images', u'target']
# GammaEscan_98GeV_fulldataset
# 98 [u'images', u'target']
# GammaEscan_99GeV_fulldataset
# 99 [u'images', u'target']
# 100 [u'images', u'target']
# GammaEscan_101GeV_fulldataset
# 101 [u'images', u'target']
# GammaEscan_102GeV_fulldataset
# 102 [u'images', u'target']
# GammaEscan_103GeV_fulldataset
# 103 [u'images', u'target']
# GammaEscan_104GeV_fulldataset
# 104 [u'images', u'target']
# GammaEscan_105GeV_fulldataset
# 105 [u'images', u'target']
# GammaEscan_106GeV_fulldataset
# 106 [u'images', u'target']
# GammaEscan_107GeV_fulldataset
# 107 [u'images', u'target']
# GammaEscan_108GeV_fulldataset
# 108 [u'images', u'target']
# GammaEscan_109GeV_fulldataset
# 109 [u'images', u'target']

# %%
#changing labels on the pion files
for i in xrange(10, 110):
    fname=("/home/kaustuv1993/Data/Energy_Scan_Pi0/Pi0Escan_%dGeV_fulldataset.h5"%i)
    f=h5py.File(fname,'r+')
    if i<100:
        fname=fname[-29:]
        fname=fname[0:26]
        print fname
    if i>100:
        fname=fname[-30:]
        fname=fname[0:27]
        print fname
    print i, f.keys()
    
    #en=int(filter(str.isdigit,(fname)))
    #print en
    #target = np.zeros((f['images'].shape[0], 2))
    #target[:,0] = 0
    #target[:,1] = en
    #f['target'] = target
    #f.close()
    #f.keys()
# Out:
# Pi0Escan_10GeV_fulldataset
# 10 [u'images', u'target']
# Pi0Escan_11GeV_fulldataset
# 11 [u'images', u'target']
# Pi0Escan_12GeV_fulldataset
# 12 [u'images', u'target']
# Pi0Escan_13GeV_fulldataset
# 13 [u'images', u'target']
# Pi0Escan_14GeV_fulldataset
# 14 [u'images', u'target']
# Pi0Escan_15GeV_fulldataset
# 15 [u'images', u'target']
# Pi0Escan_16GeV_fulldataset
# 16 [u'images', u'target']
# Pi0Escan_17GeV_fulldataset
# 17 [u'images', u'target']
# Pi0Escan_18GeV_fulldataset
# 18 [u'images', u'target']
# Pi0Escan_19GeV_fulldataset
# 19 [u'images', u'target']
# Pi0Escan_20GeV_fulldataset
# 20 [u'images', u'target']
# Pi0Escan_21GeV_fulldataset
# 21 [u'images', u'target']
# Pi0Escan_22GeV_fulldataset
# 22 [u'images', u'target']
# Pi0Escan_23GeV_fulldataset
# 23 [u'images', u'target']
# Pi0Escan_24GeV_fulldataset
# 24 [u'images', u'target']
# Pi0Escan_25GeV_fulldataset
# 25 [u'images', u'target']
# Pi0Escan_26GeV_fulldataset
# 26 [u'images', u'target']
# Pi0Escan_27GeV_fulldataset
# 27 [u'images', u'target']
# Pi0Escan_28GeV_fulldataset
# 28 [u'images', u'target']
# Pi0Escan_29GeV_fulldataset
# 29 [u'images', u'target']
# Pi0Escan_30GeV_fulldataset
# 30 [u'images', u'target']
# Pi0Escan_31GeV_fulldataset
# 31 [u'images', u'target']
# Pi0Escan_32GeV_fulldataset
# 32 [u'images', u'target']
# Pi0Escan_33GeV_fulldataset
# 33 [u'images', u'target']
# Pi0Escan_34GeV_fulldataset
# 34 [u'images', u'target']
# Pi0Escan_35GeV_fulldataset
# 35 [u'images', u'target']
# Pi0Escan_36GeV_fulldataset
# 36 [u'images', u'target']
# Pi0Escan_37GeV_fulldataset
# 37 [u'images', u'target']
# Pi0Escan_38GeV_fulldataset
# 38 [u'images', u'target']
# Pi0Escan_39GeV_fulldataset
# 39 [u'images', u'target']
# Pi0Escan_40GeV_fulldataset
# 40 [u'images', u'target']
# Pi0Escan_41GeV_fulldataset
# 41 [u'images', u'target']
# Pi0Escan_42GeV_fulldataset
# 42 [u'images', u'target']
# Pi0Escan_43GeV_fulldataset
# 43 [u'images', u'target']
# Pi0Escan_44GeV_fulldataset
# 44 [u'images', u'target']
# Pi0Escan_45GeV_fulldataset
# 45 [u'images', u'target']
# Pi0Escan_46GeV_fulldataset
# 46 [u'images', u'target']
# Pi0Escan_47GeV_fulldataset
# 47 [u'images', u'target']
# Pi0Escan_48GeV_fulldataset
# 48 [u'images', u'target']
# Pi0Escan_49GeV_fulldataset
# 49 [u'images', u'target']
# Pi0Escan_50GeV_fulldataset
# 50 [u'images', u'target']
# Pi0Escan_51GeV_fulldataset
# 51 [u'images', u'target']
# Pi0Escan_52GeV_fulldataset
# 52 [u'images', u'target']
# Pi0Escan_53GeV_fulldataset
# 53 [u'images', u'target']
# Pi0Escan_54GeV_fulldataset
# 54 [u'images', u'target']
# Pi0Escan_55GeV_fulldataset
# 55 [u'images', u'target']
# Pi0Escan_56GeV_fulldataset
# 56 [u'images', u'target']
# Pi0Escan_57GeV_fulldataset
# 57 [u'images', u'target']
# Pi0Escan_58GeV_fulldataset
# 58 [u'images', u'target']
# Pi0Escan_59GeV_fulldataset
# 59 [u'images', u'target']
# Pi0Escan_60GeV_fulldataset
# 60 [u'images', u'target']
# Pi0Escan_61GeV_fulldataset
# 61 [u'images', u'target']
# Pi0Escan_62GeV_fulldataset
# 62 [u'images', u'target']
# Pi0Escan_63GeV_fulldataset
# 63 [u'images', u'target']
# Pi0Escan_64GeV_fulldataset
# 64 [u'images', u'target']
# Pi0Escan_65GeV_fulldataset
# 65 [u'images', u'target']
# Pi0Escan_66GeV_fulldataset
# 66 [u'images', u'target']
# Pi0Escan_67GeV_fulldataset
# 67 [u'images', u'target']
# Pi0Escan_68GeV_fulldataset
# 68 [u'images', u'target']
# Pi0Escan_69GeV_fulldataset
# 69 [u'images', u'target']
# Pi0Escan_70GeV_fulldataset
# 70 [u'images', u'target']
# Pi0Escan_71GeV_fulldataset
# 71 [u'images', u'target']
# Pi0Escan_72GeV_fulldataset
# 72 [u'images', u'target']
# Pi0Escan_73GeV_fulldataset
# 73 [u'images', u'target']
# Pi0Escan_74GeV_fulldataset
# 74 [u'images', u'target']
# Pi0Escan_75GeV_fulldataset
# 75 [u'images', u'target']
# Pi0Escan_76GeV_fulldataset
# 76 [u'images', u'target']
# Pi0Escan_77GeV_fulldataset
# 77 [u'images', u'target']
# Pi0Escan_78GeV_fulldataset
# 78 [u'images', u'target']
# Pi0Escan_79GeV_fulldataset
# 79 [u'images', u'target']
# Pi0Escan_80GeV_fulldataset
# 80 [u'images', u'target']
# Pi0Escan_81GeV_fulldataset
# 81 [u'images', u'target']
# Pi0Escan_82GeV_fulldataset
# 82 [u'images', u'target']
# Pi0Escan_83GeV_fulldataset
# 83 [u'images', u'target']
# Pi0Escan_84GeV_fulldataset
# 84 [u'images', u'target']
# Pi0Escan_85GeV_fulldataset
# 85 [u'images', u'target']
# Pi0Escan_86GeV_fulldataset
# 86 [u'images', u'target']
# Pi0Escan_87GeV_fulldataset
# 87 [u'images', u'target']
# Pi0Escan_88GeV_fulldataset
# 88 [u'images', u'target']
# Pi0Escan_89GeV_fulldataset
# 89 [u'images', u'target']
# Pi0Escan_90GeV_fulldataset
# 90 [u'images', u'target']
# Pi0Escan_91GeV_fulldataset
# 91 [u'images', u'target']
# Pi0Escan_92GeV_fulldataset
# 92 [u'images', u'target']
# Pi0Escan_93GeV_fulldataset
# 93 [u'images', u'target']
# Pi0Escan_94GeV_fulldataset
# 94 [u'images', u'target']
# Pi0Escan_95GeV_fulldataset
# 95 [u'images', u'target']
# Pi0Escan_96GeV_fulldataset
# 96 [u'images', u'target']
# Pi0Escan_97GeV_fulldataset
# 97 [u'images', u'target']
# Pi0Escan_98GeV_fulldataset
# 98 [u'images', u'target']
# Pi0Escan_99GeV_fulldataset
# 99 [u'images', u'target']
# 100 [u'images', u'target']
# Pi0Escan_101GeV_fulldataset
# 101 [u'images', u'target']
# Pi0Escan_102GeV_fulldataset
# 102 [u'images', u'target']
# Pi0Escan_103GeV_fulldataset
# 103 [u'images', u'target']
# Pi0Escan_104GeV_fulldataset
# 104 [u'images', u'target']
# Pi0Escan_105GeV_fulldataset
# 105 [u'images', u'target']
# Pi0Escan_106GeV_fulldataset
# 106 [u'images', u'target']
# Pi0Escan_107GeV_fulldataset
# 107 [u'images', u'target']
# Pi0Escan_108GeV_fulldataset
# 108 [u'images', u'target']
# Pi0Escan_109GeV_fulldataset
# 109 [u'images', u'target']

# %%
for i in xrange(10, 110):
    fname0=("/home/kaustuv1993/Data/Energy_Scan_Pi0/Pi0Escan_%dGeV_fulldataset.h5"%i)
    fname1=("/home/kaustuv1993/Data/Energy_Scan_Gamma/GammaEscan_%dGeV_fulldataset.h5"%i)
    f0=h5py.File(fname0,'r+')
    f1=h5py.File(fname1,'r+')
    targetn1=f0['target']
    targetn2=f1['target']
    #print f0['target'].shape[0],f1['target'].shape[0]
# Out:
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
# 10000 10000
